# %% [markdown]
# # Faster R-CNN with Pytorch
# Source:
# https://pytorch.org/tutorials/intermediate/torchvision_tutorial.html
#
#
# ## Import things

# %%
import os
import cv2
import numpy as np
import pandas as pd
import random

import tifffile as tiff
from PIL import Image, ImageDraw
from torchvision.transforms import ToPILImage  
import matplotlib.pyplot as plt

import pycocotools

import torch
import torchvision
import torch.utils.data

from torchvision.models.detection import FasterRCNN
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.models.detection.mask_rcnn import MaskRCNNPredictor

import utils
import transforms as T
from engine import train_one_epoch, evaluate

# %%
image_path = '../train/images/slices/'
images = os.listdir(image_path)

data_path = '../CSVs'
datafiles = os.listdir(data_path)

# %% [markdown]
# ### Some functions

# %%
# this function turns the dataframe of coordinates into arrays

def parse_one_annot(path_to_data_file, filename):
    data = pd.read_csv(path_to_data_file)
    boxes_array = data[data["filename"] == filename][["xmin", "ymin",        
    "xmax", "ymax"]].values
   
    return boxes_array

# %%
## This model will give you bounding boxes and masks

def get_model(num_classes):
   # load an object detection model pre-trained on COCO
    model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=True)
    # get the number of input features for the classifier
    in_features = model.roi_heads.box_predictor.cls_score.in_features
   # replace the pre-trained head with a new on
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)
   
    return model

# %%
# This function converts an image into a PyTorch Tensor
# and flips the image horizontally sometimes during training

def get_transform(train):
    transforms = []
    transforms.append(T.ToTensor())
    if train:
      # during training, randomly flip the training images
      # and ground-truth for data augmentation
        transforms.append(T.RandomHorizontalFlip(0.5))
    return T.Compose(transforms)

# %% [markdown]
# ### Make a Glomeruli class

# %%
class GlomeruliDataset(torch.utils.data.Dataset):
    def __init__(self, root, data_file, transforms=None):
        self.root = root
        self.transforms = transforms
        self.imgs = sorted(os.listdir(os.path.join(root, 'train/images/slices')))
        self.path_to_data_file = data_file
        
    def __getitem__(self, idx):
        # load images and bounding boxes
        img_path = os.path.join(self.root,'train/images/slices', self.imgs[idx])

        img = tiff.imread(img_path)
        if len(img.shape) == 5:
            img = img.squeeze().transpose(1, 2, 0)
                    
        #boxes
        box_list = parse_one_annot(self.path_to_data_file, self.imgs[idx])
        boxes = torch.as_tensor(box_list, dtype=torch.float32)
        num_objs = len(box_list)
        
        # there is only one class
        labels = torch.ones((num_objs,), dtype=torch.int64)
        image_id = torch.tensor([idx])
        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:,0])
        
        # suppose all instances are not crowd
        iscrowd = torch.zeros((num_objs,), dtype=torch.int64)
        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        target["image_id"] = image_id
        target["area"] = area
        target["iscrowd"] = iscrowd
        if self.transforms is not None:
            img, target = self.transforms(img, target)
        return img, target
    
    def __len__(self):
        return len(self.imgs)

# %%
# Try out the class and see what it gives you:
dataset = GlomeruliDataset(root = '..', 
                           data_file = '../CSVs/glomeruli_tiles.csv')
dataset.__getitem__(111)
# Out:
# (array([[194, 112, 152, ..., 180, 187, 161],
#         [220, 137, 127, ...,  78, 132, 210],
#         [209, 152, 116, ...,  87, 104, 165],
#         ...,
#         [127, 141, 171, ..., 201, 202, 136],
#         [167, 169, 171, ..., 201, 201, 219],
#         [157, 123, 103, ..., 197, 206, 217]], dtype=uint8),
#  {'boxes': tensor([[  0., 191.,  88., 347.],
#           [  0.,  38.,  84., 104.]]),
#   'labels': tensor([1, 1]),
#   'image_id': tensor([111]),
#   'area': tensor([13728.,  5544.]),
#   'iscrowd': tensor([0, 0])})

# %% [markdown]
# ### Setting up datasets

# %%
# use our dataset and defined transformations
dataset = GlomeruliDataset(root = '..',
                           data_file = '../CSVs/glomeruli_tiles.csv', 
                           transforms = get_transform(train=True))

dataset_test = GlomeruliDataset(root = '..', 
                                data_file = '../CSVs/glomeruli_tiles.csv',
                                transforms = get_transform(train=False))

# split the dataset in train and test set
torch.manual_seed(1)
indices = torch.randperm(len(dataset)).tolist()
dataset = torch.utils.data.Subset(dataset, indices[:-200])
dataset_test = torch.utils.data.Subset(dataset_test, indices[-200:])

# define training and validation data loaders
data_loader = torch.utils.data.DataLoader(
              dataset, batch_size=1, shuffle=False, num_workers=0,
              collate_fn=utils.collate_fn)
data_loader_test = torch.utils.data.DataLoader(
         dataset_test, batch_size=1, shuffle=False, num_workers=0,
         collate_fn=utils.collate_fn)

print("We have: {} examples, {} are training and {} testing".format(len(indices), len(dataset), len(dataset_test)))
# Out:
# We have: 1797 examples, 1597 are training and 200 testing

# %%
torch.cuda.is_available()
# Out:
# True

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# our dataset has two classes only - glomeruli and not glomeruli
num_classes = 2

# get the model using our helper function
model = get_model(num_classes)

# move model to the right device
model.to(device)

# construct an optimizer
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.0001,
                            momentum=0.9, weight_decay=0.001)

# and a learning rate scheduler
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                               step_size=3,
                                               gamma=0.1)

# %%
num_epochs = 10

for epoch in range(num_epochs):  
   # train for ten epochs, printing every 200 iterations
    train_one_epoch(model, optimizer, data_loader, device, epoch,
                   print_freq=200)
    # update the learning rate
    lr_scheduler.step()
    
    #evaluate after each epoch:
    evaluate(model, data_loader_test, device=device)
# Out:
# Epoch: [0]  [   0/1597]  eta: 0:33:02  lr: 0.000000  loss: 1.1905 (1.1905)  loss_classifier: 0.7191 (0.7191)  loss_box_reg: 0.0247 (0.0247)  loss_objectness: 0.4266 (0.4266)  loss_rpn_box_reg: 0.0201 (0.0201)  time: 1.2412  data: 0.0120  max mem: 1088
# Epoch: [0]  [ 200/1597]  eta: 0:10:08  lr: 0.000020  loss: 0.3102 (0.7462)  loss_classifier: 0.1474 (0.3454)  loss_box_reg: 0.1304 (0.1263)  loss_objectness: 0.0203 (0.2463)  loss_rpn_box_reg: 0.0034 (0.0282)  time: 0.4373  data: 0.0118  max mem: 1667
# Epoch: [0]  [ 400/1597]  eta: 0:08:36  lr: 0.000040  loss: 0.3197 (0.5889)  loss_classifier: 0.1206 (0.2498)  loss_box_reg: 0.1181 (0.1377)  loss_objectness: 0.0356 (0.1778)  loss_rpn_box_reg: 0.0058 (0.0237)  time: 0.4162  data: 0.0111  max mem: 1667
# Epoch: [0]  [ 600/1597]  eta: 0:07:07  lr: 0.000060  loss: 0.2419 (0.5130)  loss_classifier: 0.1007 (0.2057)  loss_box_reg: 0.1377 (0.1378)  loss_objectness: 0.0283 (0.1455)  loss_rpn_box_reg: 0.0033 (0.0241)  time: 0.4305  data: 0.0097  max mem: 1667
# Epoch: [0]  [ 800/1597]  eta: 0:05:41  lr: 0.000080  loss: 0.2345 (0.4638)  loss_classifier: 0.0779 (0.1797)  loss_box_reg: 0.1191 (0.1417)  loss_objectness: 0.0094 (0.1190)  loss_rpn_box_reg: 0.0022 (0.0234)  time: 0.4075  data: 0.0103  max mem: 1667
# Epoch: [0]  [1000/1597]  eta: 0:04:16  lr: 0.000100  loss: 0.1874 (0.4262)  loss_classifier: 0.0561 (0.1608)  loss_box_reg: 0.1217 (0.1416)  loss_objectness: 0.0071 (0.1022)  loss_rpn_box_reg: 0.0031 (0.0215)  time: 0.4313  data: 0.0113  max mem: 1667
# Epoch: [0]  [1200/1597]  eta: 0:02:50  lr: 0.000100  loss: 0.1782 (0.3992)  loss_classifier: 0.0629 (0.1477)  loss_box_reg: 0.0897 (0.1404)  loss_objectness: 0.0123 (0.0905)  loss_rpn_box_reg: 0.0026 (0.0206)  time: 0.4191  data: 0.0108  max mem: 1667
# Epoch: [0]  [1400/1597]  eta: 0:01:24  lr: 0.000100  loss: 0.2482 (0.3805)  loss_classifier: 0.0945 (0.1384)  loss_box_reg: 0.1188 (0.1372)  loss_objectness: 0.0140 (0.0837)  loss_rpn_box_reg: 0.0033 (0.0212)  time: 0.4354  data: 0.0116  max mem: 1667
# Epoch: [0]  [1596/1597]  eta: 0:00:00  lr: 0.000100  loss: 0.1894 (0.3632)  loss_classifier: 0.0561 (0.1304)  loss_box_reg: 0.0970 (0.1338)  loss_objectness: 0.0225 (0.0778)  loss_rpn_box_reg: 0.0032 (0.0213)  time: 0.4203  data: 0.0123  max mem: 1667
# Epoch: [0] Total time: 0:11:25 (0.4291 s / it)
# creating index...
# index created!
# Test:  [  0/200]  eta: 0:00:34  model_time: 0.1630 (0.1630)  evaluator_time: 0.0019 (0.0019)  time: 0.1750  data: 0.0090  max mem: 1667
# Test:  [100/200]  eta: 0:00:17  model_time: 0.1646 (0.1636)  evaluator_time: 0.0020 (0.0018)  time: 0.1725  data: 0.0096  max mem: 1667
# Test:  [199/200]  eta: 0:00:00  model_time: 0.1720 (0.1676)  evaluator_time: 0.0020 (0.0017)  time: 0.1794  data: 0.0094  max mem: 1667
# Test: Total time: 0:00:35 (0.1793 s / it)
# ('Averaged stats:', <utils.MetricLogger object at 0x00000210352060D0>)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.488
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.753
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.580
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.274
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.626
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.370
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.586
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.594
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.058
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.496
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.711
# Epoch: [1]  [   0/1597]  eta: 0:10:54  lr: 0.000100  loss: 0.2458 (0.2458)  loss_classifier: 0.0982 (0.0982)  loss_box_reg: 0.0893 (0.0893)  loss_objectness: 0.0144 (0.0144)  loss_rpn_box_reg: 0.0439 (0.0439)  time: 0.4096  data: 0.0090  max mem: 1667
# Epoch: [1]  [ 200/1597]  eta: 0:09:55  lr: 0.000100  loss: 0.1559 (0.2291)  loss_classifier: 0.0493 (0.0737)  loss_box_reg: 0.0693 (0.1029)  loss_objectness: 0.0110 (0.0310)  loss_rpn_box_reg: 0.0028 (0.0215)  time: 0.4370  data: 0.0107  max mem: 1667
# Epoch: [1]  [ 400/1597]  eta: 0:08:30  lr: 0.000100  loss: 0.1604 (0.2253)  loss_classifier: 0.0419 (0.0728)  loss_box_reg: 0.0784 (0.1076)  loss_objectness: 0.0131 (0.0273)  loss_rpn_box_reg: 0.0048 (0.0176)  time: 0.4186  data: 0.0114  max mem: 1667
# Epoch: [1]  [ 600/1597]  eta: 0:07:04  lr: 0.000100  loss: 0.1544 (0.2164)  loss_classifier: 0.0475 (0.0687)  loss_box_reg: 0.0677 (0.1018)  loss_objectness: 0.0081 (0.0271)  loss_rpn_box_reg: 0.0021 (0.0188)  time: 0.4344  data: 0.0109  max mem: 1667
# Epoch: [1]  [ 800/1597]  eta: 0:05:39  lr: 0.000100  loss: 0.2087 (0.2119)  loss_classifier: 0.0451 (0.0674)  loss_box_reg: 0.1077 (0.1013)  loss_objectness: 0.0064 (0.0252)  loss_rpn_box_reg: 0.0018 (0.0179)  time: 0.4234  data: 0.0151  max mem: 1667
# Epoch: [1]  [1000/1597]  eta: 0:04:14  lr: 0.000100  loss: 0.1117 (0.2032)  loss_classifier: 0.0317 (0.0643)  loss_box_reg: 0.0661 (0.0977)  loss_objectness: 0.0089 (0.0246)  loss_rpn_box_reg: 0.0022 (0.0166)  time: 0.4270  data: 0.0113  max mem: 1667
# Epoch: [1]  [1200/1597]  eta: 0:02:49  lr: 0.000100  loss: 0.1221 (0.2003)  loss_classifier: 0.0381 (0.0638)  loss_box_reg: 0.0688 (0.0969)  loss_objectness: 0.0047 (0.0235)  loss_rpn_box_reg: 0.0018 (0.0161)  time: 0.4220  data: 0.0117  max mem: 1667
# Epoch: [1]  [1400/1597]  eta: 0:01:24  lr: 0.000100  loss: 0.2028 (0.2018)  loss_classifier: 0.0624 (0.0644)  loss_box_reg: 0.1001 (0.0967)  loss_objectness: 0.0143 (0.0241)  loss_rpn_box_reg: 0.0034 (0.0167)  time: 0.4292  data: 0.0099  max mem: 1667
# Epoch: [1]  [1596/1597]  eta: 0:00:00  lr: 0.000100  loss: 0.1535 (0.2009)  loss_classifier: 0.0454 (0.0640)  loss_box_reg: 0.1013 (0.0965)  loss_objectness: 0.0069 (0.0234)  loss_rpn_box_reg: 0.0019 (0.0171)  time: 0.4110  data: 0.0101  max mem: 1667
# Epoch: [1] Total time: 0:11:23 (0.4279 s / it)
# creating index...
# index created!
# Test:  [  0/200]  eta: 0:00:34  model_time: 0.1613 (0.1613)  evaluator_time: 0.0010 (0.0010)  time: 0.1733  data: 0.0090  max mem: 1667
# Test:  [100/200]  eta: 0:00:17  model_time: 0.1634 (0.1630)  evaluator_time: 0.0010 (0.0015)  time: 0.1724  data: 0.0095  max mem: 1667
# Test:  [199/200]  eta: 0:00:00  model_time: 0.1720 (0.1675)  evaluator_time: 0.0020 (0.0015)  time: 0.1788  data: 0.0093  max mem: 1667
# Test: Total time: 0:00:35 (0.1791 s / it)
# ('Averaged stats:', <utils.MetricLogger object at 0x0000021035242700>)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.543
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.814
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.638
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.008
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.373
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.674
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.389
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.626
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.628
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.094
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.533
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.742
# Epoch: [2]  [   0/1597]  eta: 0:10:37  lr: 0.000100  loss: 0.1882 (0.1882)  loss_classifier: 0.0524 (0.0524)  loss_box_reg: 0.0888 (0.0888)  loss_objectness: 0.0036 (0.0036)  loss_rpn_box_reg: 0.0434 (0.0434)  time: 0.3989  data: 0.0090  max mem: 1667
# Epoch: [2]  [ 200/1597]  eta: 0:09:55  lr: 0.000100  loss: 0.1240 (0.1897)  loss_classifier: 0.0382 (0.0611)  loss_box_reg: 0.0543 (0.0879)  loss_objectness: 0.0071 (0.0222)  loss_rpn_box_reg: 0.0019 (0.0186)  time: 0.4324  data: 0.0101  max mem: 1667
# Epoch: [2]  [ 400/1597]  eta: 0:08:30  lr: 0.000100  loss: 0.1357 (0.1902)  loss_classifier: 0.0387 (0.0623)  loss_box_reg: 0.0720 (0.0943)  loss_objectness: 0.0091 (0.0184)  loss_rpn_box_reg: 0.0040 (0.0153)  time: 0.4180  data: 0.0113  max mem: 1667
# Epoch: [2]  [ 600/1597]  eta: 0:07:04  lr: 0.000100  loss: 0.1041 (0.1844)  loss_classifier: 0.0492 (0.0596)  loss_box_reg: 0.0556 (0.0903)  loss_objectness: 0.0046 (0.0181)  loss_rpn_box_reg: 0.0021 (0.0164)  time: 0.4366  data: 0.0108  max mem: 1667
# Epoch: [2]  [ 800/1597]  eta: 0:05:40  lr: 0.000100  loss: 0.1709 (0.1835)  loss_classifier: 0.0444 (0.0597)  loss_box_reg: 0.0831 (0.0909)  loss_objectness: 0.0064 (0.0168)  loss_rpn_box_reg: 0.0017 (0.0161)  time: 0.4169  data: 0.0127  max mem: 1667
# Epoch: [2]  [1000/1597]  eta: 0:04:15  lr: 0.000100  loss: 0.0955 (0.1776)  loss_classifier: 0.0288 (0.0572)  loss_box_reg: 0.0540 (0.0883)  loss_objectness: 0.0050 (0.0170)  loss_rpn_box_reg: 0.0027 (0.0152)  time: 0.4273  data: 0.0104  max mem: 1667
# Epoch: [2]  [1200/1597]  eta: 0:02:49  lr: 0.000100  loss: 0.1177 (0.1764)  loss_classifier: 0.0294 (0.0573)  loss_box_reg: 0.0592 (0.0880)  loss_objectness: 0.0082 (0.0164)  loss_rpn_box_reg: 0.0018 (0.0147)  time: 0.4177  data: 0.0104  max mem: 1667
# Epoch: [2]  [1400/1597]  eta: 0:01:24  lr: 0.000100  loss: 0.1677 (0.1777)  loss_classifier: 0.0520 (0.0577)  loss_box_reg: 0.0885 (0.0881)  loss_objectness: 0.0098 (0.0167)  loss_rpn_box_reg: 0.0027 (0.0152)  time: 0.4329  data: 0.0104  max mem: 1667
# Epoch: [2]  [1596/1597]  eta: 0:00:00  lr: 0.000100  loss: 0.1504 (0.1777)  loss_classifier: 0.0500 (0.0574)  loss_box_reg: 0.0829 (0.0880)  loss_objectness: 0.0099 (0.0168)  loss_rpn_box_reg: 0.0024 (0.0155)  time: 0.4207  data: 0.0122  max mem: 1667
# Epoch: [2] Total time: 0:11:23 (0.4280 s / it)
# creating index...
# index created!
# Test:  [  0/200]  eta: 0:00:34  model_time: 0.1618 (0.1618)  evaluator_time: 0.0010 (0.0010)  time: 0.1737  data: 0.0090  max mem: 1667
# Test:  [100/200]  eta: 0:00:17  model_time: 0.1674 (0.1633)  evaluator_time: 0.0010 (0.0015)  time: 0.1734  data: 0.0095  max mem: 1667
# Test:  [199/200]  eta: 0:00:00  model_time: 0.1701 (0.1676)  evaluator_time: 0.0020 (0.0015)  time: 0.1787  data: 0.0092  max mem: 1667
# Test: Total time: 0:00:35 (0.1790 s / it)
# ('Averaged stats:', <utils.MetricLogger object at 0x00000210353E0B20>)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.565
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.825
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.665
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.008
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.414
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.694
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.410
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.646
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.649
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.077
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.576
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.760
# Epoch: [3]  [   0/1597]  eta: 0:10:56  lr: 0.000010  loss: 0.1911 (0.1911)  loss_classifier: 0.0543 (0.0543)  loss_box_reg: 0.0960 (0.0960)  loss_objectness: 0.0038 (0.0038)  loss_rpn_box_reg: 0.0370 (0.0370)  time: 0.4109  data: 0.0100  max mem: 1667
# Epoch: [3]  [ 200/1597]  eta: 0:09:53  lr: 0.000010  loss: 0.1337 (0.1788)  loss_classifier: 0.0310 (0.0561)  loss_box_reg: 0.0675 (0.0832)  loss_objectness: 0.0044 (0.0199)  loss_rpn_box_reg: 0.0020 (0.0195)  time: 0.4303  data: 0.0099  max mem: 1667
# Epoch: [3]  [ 400/1597]  eta: 0:08:29  lr: 0.000010  loss: 0.1641 (0.1787)  loss_classifier: 0.0354 (0.0579)  loss_box_reg: 0.0698 (0.0899)  loss_objectness: 0.0069 (0.0156)  loss_rpn_box_reg: 0.0047 (0.0154)  time: 0.4205  data: 0.0118  max mem: 1667
# Epoch: [3]  [ 600/1597]  eta: 0:07:06  lr: 0.000010  loss: 0.1176 (0.1736)  loss_classifier: 0.0399 (0.0559)  loss_box_reg: 0.0537 (0.0860)  loss_objectness: 0.0051 (0.0154)  loss_rpn_box_reg: 0.0013 (0.0162)  time: 0.4427  data: 0.0129  max mem: 1667
# Epoch: [3]  [ 800/1597]  eta: 0:05:40  lr: 0.000010  loss: 0.1680 (0.1712)  loss_classifier: 0.0413 (0.0556)  loss_box_reg: 0.0741 (0.0861)  loss_objectness: 0.0063 (0.0143)  loss_rpn_box_reg: 0.0014 (0.0152)  time: 0.4129  data: 0.0116  max mem: 1667
# Epoch: [3]  [1000/1597]  eta: 0:04:15  lr: 0.000010  loss: 0.0923 (0.1672)  loss_classifier: 0.0308 (0.0545)  loss_box_reg: 0.0606 (0.0842)  loss_objectness: 0.0048 (0.0142)  loss_rpn_box_reg: 0.0025 (0.0144)  time: 0.4207  data: 0.0099  max mem: 1667
# Epoch: [3]  [1200/1597]  eta: 0:02:49  lr: 0.000010  loss: 0.1080 (0.1667)  loss_classifier: 0.0310 (0.0546)  loss_box_reg: 0.0463 (0.0845)  loss_objectness: 0.0040 (0.0137)  loss_rpn_box_reg: 0.0014 (0.0139)  time: 0.4136  data: 0.0097  max mem: 1667
# Epoch: [3]  [1400/1597]  eta: 0:01:24  lr: 0.000010  loss: 0.1465 (0.1669)  loss_classifier: 0.0471 (0.0548)  loss_box_reg: 0.0904 (0.0844)  loss_objectness: 0.0067 (0.0135)  loss_rpn_box_reg: 0.0023 (0.0142)  time: 0.4349  data: 0.0107  max mem: 1667
# Epoch: [3]  [1596/1597]  eta: 0:00:00  lr: 0.000010  loss: 0.1417 (0.1665)  loss_classifier: 0.0388 (0.0546)  loss_box_reg: 0.0832 (0.0845)  loss_objectness: 0.0043 (0.0131)  loss_rpn_box_reg: 0.0021 (0.0143)  time: 0.4143  data: 0.0107  max mem: 1667
# Epoch: [3] Total time: 0:11:22 (0.4271 s / it)
# creating index...
# index created!
# Test:  [  0/200]  eta: 0:00:34  model_time: 0.1616 (0.1616)  evaluator_time: 0.0010 (0.0010)  time: 0.1725  data: 0.0080  max mem: 1667
# Test:  [100/200]  eta: 0:00:17  model_time: 0.1656 (0.1635)  evaluator_time: 0.0020 (0.0017)  time: 0.1734  data: 0.0095  max mem: 1667
# Test:  [199/200]  eta: 0:00:00  model_time: 0.1703 (0.1672)  evaluator_time: 0.0020 (0.0017)  time: 0.1776  data: 0.0093  max mem: 1667
# Test: Total time: 0:00:35 (0.1788 s / it)
# ('Averaged stats:', <utils.MetricLogger object at 0x0000021035243CA0>)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.579
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.830
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.674
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.009
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.426
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.710
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.413
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.658
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.666
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.084
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.589
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.779
# Epoch: [4]  [   0/1597]  eta: 0:10:29  lr: 0.000010  loss: 0.1585 (0.1585)  loss_classifier: 0.0363 (0.0363)  loss_box_reg: 0.0906 (0.0906)  loss_objectness: 0.0018 (0.0018)  loss_rpn_box_reg: 0.0298 (0.0298)  time: 0.3944  data: 0.0090  max mem: 1667
# Epoch: [4]  [ 200/1597]  eta: 0:10:01  lr: 0.000010  loss: 0.1040 (0.1738)  loss_classifier: 0.0333 (0.0562)  loss_box_reg: 0.0733 (0.0824)  loss_objectness: 0.0031 (0.0167)  loss_rpn_box_reg: 0.0018 (0.0185)  time: 0.4401  data: 0.0125  max mem: 1667
# Epoch: [4]  [ 400/1597]  eta: 0:08:32  lr: 0.000010  loss: 0.1509 (0.1740)  loss_classifier: 0.0401 (0.0572)  loss_box_reg: 0.0625 (0.0885)  loss_objectness: 0.0073 (0.0136)  loss_rpn_box_reg: 0.0027 (0.0146)  time: 0.4168  data: 0.0114  max mem: 1667
# Epoch: [4]  [ 600/1597]  eta: 0:07:06  lr: 0.000010  loss: 0.1129 (0.1689)  loss_classifier: 0.0451 (0.0551)  loss_box_reg: 0.0596 (0.0851)  loss_objectness: 0.0051 (0.0132)  loss_rpn_box_reg: 0.0017 (0.0155)  time: 0.4444  data: 0.0132  max mem: 1667
# Epoch: [4]  [ 800/1597]  eta: 0:05:41  lr: 0.000010  loss: 0.1645 (0.1670)  loss_classifier: 0.0424 (0.0546)  loss_box_reg: 0.0734 (0.0855)  loss_objectness: 0.0046 (0.0122)  loss_rpn_box_reg: 0.0014 (0.0147)  time: 0.4178  data: 0.0118  max mem: 1667
# Epoch: [4]  [1000/1597]  eta: 0:04:16  lr: 0.000010  loss: 0.0881 (0.1626)  loss_classifier: 0.0277 (0.0534)  loss_box_reg: 0.0564 (0.0832)  loss_objectness: 0.0068 (0.0123)  loss_rpn_box_reg: 0.0026 (0.0138)  time: 0.4315  data: 0.0122  max mem: 1667
# Epoch: [4]  [1200/1597]  eta: 0:02:50  lr: 0.000010  loss: 0.0908 (0.1620)  loss_classifier: 0.0348 (0.0535)  loss_box_reg: 0.0486 (0.0834)  loss_objectness: 0.0025 (0.0118)  loss_rpn_box_reg: 0.0016 (0.0134)  time: 0.4210  data: 0.0116  max mem: 1667
# Epoch: [4]  [1400/1597]  eta: 0:01:24  lr: 0.000010  loss: 0.1484 (0.1624)  loss_classifier: 0.0521 (0.0536)  loss_box_reg: 0.0893 (0.0831)  loss_objectness: 0.0044 (0.0120)  loss_rpn_box_reg: 0.0033 (0.0137)  time: 0.4385  data: 0.0129  max mem: 1667
# Epoch: [4]  [1596/1597]  eta: 0:00:00  lr: 0.000010  loss: 0.1406 (0.1623)  loss_classifier: 0.0418 (0.0535)  loss_box_reg: 0.0795 (0.0831)  loss_objectness: 0.0046 (0.0117)  loss_rpn_box_reg: 0.0019 (0.0139)  time: 0.4188  data: 0.0119  max mem: 1667
# Epoch: [4] Total time: 0:11:24 (0.4288 s / it)
# creating index...
# index created!
# Test:  [  0/200]  eta: 0:00:34  model_time: 0.1590 (0.1590)  evaluator_time: 0.0010 (0.0010)  time: 0.1710  data: 0.0090  max mem: 1667
# Test:  [100/200]  eta: 0:00:17  model_time: 0.1636 (0.1628)  evaluator_time: 0.0011 (0.0016)  time: 0.1712  data: 0.0095  max mem: 1667
# Test:  [199/200]  eta: 0:00:00  model_time: 0.1697 (0.1668)  evaluator_time: 0.0020 (0.0016)  time: 0.1780  data: 0.0096  max mem: 1667
# Test: Total time: 0:00:35 (0.1790 s / it)
# ('Averaged stats:', <utils.MetricLogger object at 0x0000021035221A00>)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.575
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.831
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.677
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.011
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.427
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.704
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.416
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.655
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.656
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.094
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.571
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.770
# Epoch: [5]  [   0/1597]  eta: 0:10:45  lr: 0.000010  loss: 0.1597 (0.1597)  loss_classifier: 0.0286 (0.0286)  loss_box_reg: 0.0741 (0.0741)  loss_objectness: 0.0303 (0.0303)  loss_rpn_box_reg: 0.0266 (0.0266)  time: 0.4045  data: 0.0100  max mem: 1667
# Epoch: [5]  [ 200/1597]  eta: 0:09:53  lr: 0.000010  loss: 0.1080 (0.1705)  loss_classifier: 0.0336 (0.0554)  loss_box_reg: 0.0741 (0.0819)  loss_objectness: 0.0040 (0.0161)  loss_rpn_box_reg: 0.0018 (0.0171)  time: 0.4278  data: 0.0098  max mem: 1667
# Epoch: [5]  [ 400/1597]  eta: 0:08:28  lr: 0.000010  loss: 0.1355 (0.1709)  loss_classifier: 0.0370 (0.0559)  loss_box_reg: 0.0625 (0.0876)  loss_objectness: 0.0083 (0.0135)  loss_rpn_box_reg: 0.0028 (0.0140)  time: 0.4117  data: 0.0103  max mem: 1667
# Epoch: [5]  [ 600/1597]  eta: 0:07:03  lr: 0.000010  loss: 0.1038 (0.1661)  loss_classifier: 0.0365 (0.0542)  loss_box_reg: 0.0554 (0.0843)  loss_objectness: 0.0041 (0.0128)  loss_rpn_box_reg: 0.0014 (0.0148)  time: 0.4296  data: 0.0098  max mem: 1667
# Epoch: [5]  [ 800/1597]  eta: 0:05:38  lr: 0.000010  loss: 0.1413 (0.1644)  loss_classifier: 0.0412 (0.0539)  loss_box_reg: 0.0735 (0.0844)  loss_objectness: 0.0044 (0.0120)  loss_rpn_box_reg: 0.0013 (0.0141)  time: 0.4148  data: 0.0116  max mem: 1667
# Epoch: [5]  [1000/1597]  eta: 0:04:14  lr: 0.000010  loss: 0.0905 (0.1613)  loss_classifier: 0.0238 (0.0527)  loss_box_reg: 0.0610 (0.0827)  loss_objectness: 0.0052 (0.0125)  loss_rpn_box_reg: 0.0024 (0.0135)  time: 0.4233  data: 0.0100  max mem: 1667
# Epoch: [5]  [1200/1597]  eta: 0:02:49  lr: 0.000010  loss: 0.0925 (0.1607)  loss_classifier: 0.0296 (0.0528)  loss_box_reg: 0.0462 (0.0827)  loss_objectness: 0.0031 (0.0120)  loss_rpn_box_reg: 0.0015 (0.0131)  time: 0.4248  data: 0.0122  max mem: 1667
# Epoch: [5]  [1400/1597]  eta: 0:01:24  lr: 0.000010  loss: 0.1431 (0.1616)  loss_classifier: 0.0459 (0.0533)  loss_box_reg: 0.0747 (0.0828)  loss_objectness: 0.0075 (0.0121)  loss_rpn_box_reg: 0.0031 (0.0135)  time: 0.4343  data: 0.0115  max mem: 1667
# Epoch: [5]  [1596/1597]  eta: 0:00:00  lr: 0.000010  loss: 0.1395 (0.1613)  loss_classifier: 0.0368 (0.0531)  loss_box_reg: 0.0821 (0.0828)  loss_objectness: 0.0037 (0.0117)  loss_rpn_box_reg: 0.0023 (0.0137)  time: 0.4093  data: 0.0101  max mem: 1667
# Epoch: [5] Total time: 0:11:21 (0.4266 s / it)
# creating index...
# index created!
# Test:  [  0/200]  eta: 0:00:33  model_time: 0.1579 (0.1579)  evaluator_time: 0.0010 (0.0010)  time: 0.1689  data: 0.0090  max mem: 1667
# Test:  [100/200]  eta: 0:00:17  model_time: 0.1646 (0.1625)  evaluator_time: 0.0010 (0.0015)  time: 0.1722  data: 0.0096  max mem: 1667
# Test:  [199/200]  eta: 0:00:00  model_time: 0.1702 (0.1663)  evaluator_time: 0.0020 (0.0015)  time: 0.1776  data: 0.0093  max mem: 1667
# Test: Total time: 0:00:35 (0.1777 s / it)
# ('Averaged stats:', <utils.MetricLogger object at 0x00000210351E3A60>)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.576
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.831
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.671
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.011
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.431
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.702
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.416
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.658
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.658
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.087
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.583
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.769
# Epoch: [6]  [   0/1597]  eta: 0:10:48  lr: 0.000001  loss: 0.1482 (0.1482)  loss_classifier: 0.0317 (0.0317)  loss_box_reg: 0.0867 (0.0867)  loss_objectness: 0.0017 (0.0017)  loss_rpn_box_reg: 0.0280 (0.0280)  time: 0.4063  data: 0.0093  max mem: 1667
# Epoch: [6]  [ 200/1597]  eta: 0:09:53  lr: 0.000001  loss: 0.0976 (0.1647)  loss_classifier: 0.0379 (0.0541)  loss_box_reg: 0.0603 (0.0813)  loss_objectness: 0.0028 (0.0136)  loss_rpn_box_reg: 0.0015 (0.0157)  time: 0.4324  data: 0.0107  max mem: 1667
# Epoch: [6]  [ 400/1597]  eta: 0:08:28  lr: 0.000001  loss: 0.1425 (0.1682)  loss_classifier: 0.0367 (0.0553)  loss_box_reg: 0.0671 (0.0879)  loss_objectness: 0.0056 (0.0120)  loss_rpn_box_reg: 0.0027 (0.0130)  time: 0.4091  data: 0.0098  max mem: 1667
# Epoch: [6]  [ 600/1597]  eta: 0:07:02  lr: 0.000001  loss: 0.1248 (0.1650)  loss_classifier: 0.0458 (0.0541)  loss_box_reg: 0.0536 (0.0847)  loss_objectness: 0.0050 (0.0118)  loss_rpn_box_reg: 0.0017 (0.0145)  time: 0.4363  data: 0.0109  max mem: 1667
# Epoch: [6]  [ 800/1597]  eta: 0:05:38  lr: 0.000001  loss: 0.1735 (0.1635)  loss_classifier: 0.0450 (0.0537)  loss_box_reg: 0.0747 (0.0848)  loss_objectness: 0.0081 (0.0113)  loss_rpn_box_reg: 0.0014 (0.0137)  time: 0.4097  data: 0.0110  max mem: 1667
# Epoch: [6]  [1000/1597]  eta: 0:04:14  lr: 0.000001  loss: 0.0863 (0.1597)  loss_classifier: 0.0336 (0.0525)  loss_box_reg: 0.0573 (0.0828)  loss_objectness: 0.0033 (0.0113)  loss_rpn_box_reg: 0.0026 (0.0131)  time: 0.4369  data: 0.0142  max mem: 1667
# Epoch: [6]  [1200/1597]  eta: 0:02:49  lr: 0.000001  loss: 0.0959 (0.1595)  loss_classifier: 0.0283 (0.0527)  loss_box_reg: 0.0596 (0.0829)  loss_objectness: 0.0023 (0.0110)  loss_rpn_box_reg: 0.0013 (0.0129)  time: 0.4229  data: 0.0118  max mem: 1667
# Epoch: [6]  [1400/1597]  eta: 0:01:24  lr: 0.000001  loss: 0.1470 (0.1604)  loss_classifier: 0.0543 (0.0530)  loss_box_reg: 0.0809 (0.0829)  loss_objectness: 0.0042 (0.0112)  loss_rpn_box_reg: 0.0025 (0.0133)  time: 0.4323  data: 0.0108  max mem: 1667
# Epoch: [6]  [1596/1597]  eta: 0:00:00  lr: 0.000001  loss: 0.1305 (0.1605)  loss_classifier: 0.0451 (0.0530)  loss_box_reg: 0.0788 (0.0830)  loss_objectness: 0.0038 (0.0110)  loss_rpn_box_reg: 0.0027 (0.0135)  time: 0.4080  data: 0.0097  max mem: 1667
# Epoch: [6] Total time: 0:11:21 (0.4265 s / it)
# creating index...
# index created!
# Test:  [  0/200]  eta: 0:00:34  model_time: 0.1608 (0.1608)  evaluator_time: 0.0010 (0.0010)  time: 0.1738  data: 0.0090  max mem: 1667
# Test:  [100/200]  eta: 0:00:17  model_time: 0.1660 (0.1628)  evaluator_time: 0.0011 (0.0015)  time: 0.1730  data: 0.0097  max mem: 1667
# Test:  [199/200]  eta: 0:00:00  model_time: 0.1691 (0.1669)  evaluator_time: 0.0010 (0.0015)  time: 0.1771  data: 0.0092  max mem: 1667
# Test: Total time: 0:00:35 (0.1785 s / it)
# ('Averaged stats:', <utils.MetricLogger object at 0x000002103521EDF0>)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.577
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.832
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.674
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.013
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.425
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.706
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.412
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.657
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.658
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.097
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.576
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.771
# Epoch: [7]  [   0/1597]  eta: 0:10:24  lr: 0.000001  loss: 0.1286 (0.1286)  loss_classifier: 0.0307 (0.0307)  loss_box_reg: 0.0703 (0.0703)  loss_objectness: 0.0027 (0.0027)  loss_rpn_box_reg: 0.0250 (0.0250)  time: 0.3911  data: 0.0109  max mem: 1667
# Epoch: [7]  [ 200/1597]  eta: 0:10:00  lr: 0.000001  loss: 0.1087 (0.1644)  loss_classifier: 0.0309 (0.0538)  loss_box_reg: 0.0734 (0.0802)  loss_objectness: 0.0044 (0.0139)  loss_rpn_box_reg: 0.0017 (0.0165)  time: 0.4365  data: 0.0112  max mem: 1667
# Epoch: [7]  [ 400/1597]  eta: 0:08:32  lr: 0.000001  loss: 0.1464 (0.1682)  loss_classifier: 0.0335 (0.0553)  loss_box_reg: 0.0686 (0.0875)  loss_objectness: 0.0044 (0.0119)  loss_rpn_box_reg: 0.0036 (0.0134)  time: 0.4171  data: 0.0108  max mem: 1667
# Epoch: [7]  [ 600/1597]  eta: 0:07:06  lr: 0.000001  loss: 0.0964 (0.1640)  loss_classifier: 0.0389 (0.0539)  loss_box_reg: 0.0510 (0.0839)  loss_objectness: 0.0045 (0.0116)  loss_rpn_box_reg: 0.0014 (0.0146)  time: 0.4409  data: 0.0119  max mem: 1667
# Epoch: [7]  [ 800/1597]  eta: 0:05:40  lr: 0.000001  loss: 0.1586 (0.1623)  loss_classifier: 0.0402 (0.0534)  loss_box_reg: 0.0749 (0.0842)  loss_objectness: 0.0043 (0.0109)  loss_rpn_box_reg: 0.0015 (0.0138)  time: 0.4064  data: 0.0101  max mem: 1667
# Epoch: [7]  [1000/1597]  eta: 0:04:15  lr: 0.000001  loss: 0.0890 (0.1590)  loss_classifier: 0.0312 (0.0522)  loss_box_reg: 0.0566 (0.0824)  loss_objectness: 0.0050 (0.0113)  loss_rpn_box_reg: 0.0023 (0.0132)  time: 0.4268  data: 0.0110  max mem: 1667
# Epoch: [7]  [1200/1597]  eta: 0:02:49  lr: 0.000001  loss: 0.0911 (0.1589)  loss_classifier: 0.0323 (0.0523)  loss_box_reg: 0.0452 (0.0826)  loss_objectness: 0.0050 (0.0110)  loss_rpn_box_reg: 0.0017 (0.0129)  time: 0.4179  data: 0.0105  max mem: 1667
# Epoch: [7]  [1400/1597]  eta: 0:01:24  lr: 0.000001  loss: 0.1597 (0.1595)  loss_classifier: 0.0522 (0.0527)  loss_box_reg: 0.0913 (0.0825)  loss_objectness: 0.0042 (0.0111)  loss_rpn_box_reg: 0.0025 (0.0133)  time: 0.4308  data: 0.0104  max mem: 1667
# Epoch: [7]  [1596/1597]  eta: 0:00:00  lr: 0.000001  loss: 0.1322 (0.1595)  loss_classifier: 0.0397 (0.0526)  loss_box_reg: 0.0766 (0.0825)  loss_objectness: 0.0037 (0.0109)  loss_rpn_box_reg: 0.0019 (0.0135)  time: 0.4203  data: 0.0121  max mem: 1667
# Epoch: [7] Total time: 0:11:22 (0.4274 s / it)
# creating index...
# index created!
# Test:  [  0/200]  eta: 0:00:34  model_time: 0.1610 (0.1610)  evaluator_time: 0.0010 (0.0010)  time: 0.1730  data: 0.0090  max mem: 1667
# Test:  [100/200]  eta: 0:00:17  model_time: 0.1658 (0.1625)  evaluator_time: 0.0010 (0.0014)  time: 0.1720  data: 0.0095  max mem: 1667
# Test:  [199/200]  eta: 0:00:00  model_time: 0.1715 (0.1669)  evaluator_time: 0.0020 (0.0015)  time: 0.1778  data: 0.0093  max mem: 1667
# Test: Total time: 0:00:35 (0.1783 s / it)
# ('Averaged stats:', <utils.MetricLogger object at 0x0000021035206820>)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.577
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.832
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.676
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.013
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.426
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.704
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.414
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.657
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.657
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.087
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.577
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.770
# Epoch: [8]  [   0/1597]  eta: 0:10:43  lr: 0.000001  loss: 0.1283 (0.1283)  loss_classifier: 0.0304 (0.0304)  loss_box_reg: 0.0701 (0.0701)  loss_objectness: 0.0030 (0.0030)  loss_rpn_box_reg: 0.0248 (0.0248)  time: 0.4032  data: 0.0112  max mem: 1667
# Epoch: [8]  [ 200/1597]  eta: 0:09:56  lr: 0.000001  loss: 0.1144 (0.1632)  loss_classifier: 0.0337 (0.0541)  loss_box_reg: 0.0749 (0.0804)  loss_objectness: 0.0039 (0.0134)  loss_rpn_box_reg: 0.0014 (0.0153)  time: 0.4328  data: 0.0103  max mem: 1667
# Epoch: [8]  [ 400/1597]  eta: 0:08:34  lr: 0.000001  loss: 0.1433 (0.1682)  loss_classifier: 0.0286 (0.0553)  loss_box_reg: 0.0677 (0.0885)  loss_objectness: 0.0058 (0.0116)  loss_rpn_box_reg: 0.0043 (0.0128)  time: 0.4228  data: 0.0133  max mem: 1667
# Epoch: [8]  [ 600/1597]  eta: 0:07:08  lr: 0.000001  loss: 0.1117 (0.1640)  loss_classifier: 0.0399 (0.0535)  loss_box_reg: 0.0511 (0.0848)  loss_objectness: 0.0067 (0.0116)  loss_rpn_box_reg: 0.0017 (0.0140)  time: 0.4410  data: 0.0116  max mem: 1667
# Epoch: [8]  [ 800/1597]  eta: 0:05:41  lr: 0.000001  loss: 0.1553 (0.1626)  loss_classifier: 0.0476 (0.0535)  loss_box_reg: 0.0702 (0.0848)  loss_objectness: 0.0045 (0.0109)  loss_rpn_box_reg: 0.0015 (0.0134)  time: 0.4071  data: 0.0099  max mem: 1667
# Epoch: [8]  [1000/1597]  eta: 0:04:16  lr: 0.000001  loss: 0.0841 (0.1591)  loss_classifier: 0.0269 (0.0522)  loss_box_reg: 0.0555 (0.0828)  loss_objectness: 0.0031 (0.0112)  loss_rpn_box_reg: 0.0026 (0.0129)  time: 0.4274  data: 0.0110  max mem: 1667
# Epoch: [8]  [1200/1597]  eta: 0:02:50  lr: 0.000001  loss: 0.0895 (0.1586)  loss_classifier: 0.0275 (0.0523)  loss_box_reg: 0.0616 (0.0829)  loss_objectness: 0.0035 (0.0109)  loss_rpn_box_reg: 0.0013 (0.0125)  time: 0.4135  data: 0.0098  max mem: 1667
# Epoch: [8]  [1400/1597]  eta: 0:01:24  lr: 0.000001  loss: 0.1588 (0.1593)  loss_classifier: 0.0509 (0.0525)  loss_box_reg: 0.0894 (0.0828)  loss_objectness: 0.0068 (0.0110)  loss_rpn_box_reg: 0.0025 (0.0130)  time: 0.4333  data: 0.0110  max mem: 1667
# Epoch: [8]  [1596/1597]  eta: 0:00:00  lr: 0.000001  loss: 0.1244 (0.1596)  loss_classifier: 0.0409 (0.0526)  loss_box_reg: 0.0782 (0.0828)  loss_objectness: 0.0053 (0.0109)  loss_rpn_box_reg: 0.0017 (0.0133)  time: 0.4148  data: 0.0111  max mem: 1667
# Epoch: [8] Total time: 0:11:23 (0.4280 s / it)
# creating index...
# index created!
# Test:  [  0/200]  eta: 0:00:33  model_time: 0.1580 (0.1580)  evaluator_time: 0.0020 (0.0020)  time: 0.1700  data: 0.0079  max mem: 1667
# Test:  [100/200]  eta: 0:00:17  model_time: 0.1655 (0.1651)  evaluator_time: 0.0010 (0.0016)  time: 0.1746  data: 0.0116  max mem: 1667
# Test:  [199/200]  eta: 0:00:00  model_time: 0.1691 (0.1686)  evaluator_time: 0.0010 (0.0016)  time: 0.1769  data: 0.0095  max mem: 1667
# Test: Total time: 0:00:36 (0.1815 s / it)
# ('Averaged stats:', <utils.MetricLogger object at 0x000002103521E0D0>)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.576
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.829
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.679
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.013
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.426
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.706
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.412
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.656
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.656
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.084
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.571
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.771
# Epoch: [9]  [   0/1597]  eta: 0:10:45  lr: 0.000000  loss: 0.1256 (0.1256)  loss_classifier: 0.0294 (0.0294)  loss_box_reg: 0.0699 (0.0699)  loss_objectness: 0.0016 (0.0016)  loss_rpn_box_reg: 0.0247 (0.0247)  time: 0.4043  data: 0.0100  max mem: 1667
# Epoch: [9]  [ 200/1597]  eta: 0:09:55  lr: 0.000000  loss: 0.1176 (0.1675)  loss_classifier: 0.0369 (0.0540)  loss_box_reg: 0.0748 (0.0805)  loss_objectness: 0.0034 (0.0155)  loss_rpn_box_reg: 0.0015 (0.0176)  time: 0.4331  data: 0.0111  max mem: 1667
# Epoch: [9]  [ 400/1597]  eta: 0:08:30  lr: 0.000000  loss: 0.1357 (0.1698)  loss_classifier: 0.0359 (0.0556)  loss_box_reg: 0.0666 (0.0872)  loss_objectness: 0.0049 (0.0130)  loss_rpn_box_reg: 0.0036 (0.0141)  time: 0.4177  data: 0.0118  max mem: 1667
# Epoch: [9]  [ 600/1597]  eta: 0:07:03  lr: 0.000000  loss: 0.1015 (0.1648)  loss_classifier: 0.0354 (0.0538)  loss_box_reg: 0.0522 (0.0838)  loss_objectness: 0.0058 (0.0123)  loss_rpn_box_reg: 0.0017 (0.0149)  time: 0.4327  data: 0.0110  max mem: 1667
# Epoch: [9]  [ 800/1597]  eta: 0:05:38  lr: 0.000000  loss: 0.1614 (0.1635)  loss_classifier: 0.0322 (0.0535)  loss_box_reg: 0.0700 (0.0842)  loss_objectness: 0.0048 (0.0118)  loss_rpn_box_reg: 0.0015 (0.0140)  time: 0.4088  data: 0.0109  max mem: 1667
# Epoch: [9]  [1000/1597]  eta: 0:04:14  lr: 0.000000  loss: 0.0904 (0.1595)  loss_classifier: 0.0336 (0.0521)  loss_box_reg: 0.0545 (0.0823)  loss_objectness: 0.0044 (0.0118)  loss_rpn_box_reg: 0.0026 (0.0134)  time: 0.4266  data: 0.0106  max mem: 1667
# Epoch: [9]  [1200/1597]  eta: 0:02:49  lr: 0.000000  loss: 0.1046 (0.1591)  loss_classifier: 0.0287 (0.0523)  loss_box_reg: 0.0616 (0.0823)  loss_objectness: 0.0070 (0.0114)  loss_rpn_box_reg: 0.0013 (0.0130)  time: 0.4198  data: 0.0112  max mem: 1667
# Epoch: [9]  [1400/1597]  eta: 0:01:23  lr: 0.000000  loss: 0.1562 (0.1600)  loss_classifier: 0.0505 (0.0528)  loss_box_reg: 0.0895 (0.0826)  loss_objectness: 0.0060 (0.0113)  loss_rpn_box_reg: 0.0026 (0.0133)  time: 0.4400  data: 0.0122  max mem: 1667
# Epoch: [9]  [1596/1597]  eta: 0:00:00  lr: 0.000000  loss: 0.1268 (0.1597)  loss_classifier: 0.0339 (0.0527)  loss_box_reg: 0.0784 (0.0825)  loss_objectness: 0.0040 (0.0111)  loss_rpn_box_reg: 0.0016 (0.0135)  time: 0.4158  data: 0.0116  max mem: 1667
# Epoch: [9] Total time: 0:11:21 (0.4270 s / it)
# creating index...
# index created!
# Test:  [  0/200]  eta: 0:00:34  model_time: 0.1616 (0.1616)  evaluator_time: 0.0010 (0.0010)  time: 0.1725  data: 0.0090  max mem: 1667
# Test:  [100/200]  eta: 0:00:17  model_time: 0.1652 (0.1641)  evaluator_time: 0.0020 (0.0015)  time: 0.1728  data: 0.0096  max mem: 1667
# Test:  [199/200]  eta: 0:00:00  model_time: 0.1707 (0.1677)  evaluator_time: 0.0020 (0.0015)  time: 0.1773  data: 0.0093  max mem: 1667
# Test: Total time: 0:00:35 (0.1791 s / it)
# ('Averaged stats:', <utils.MetricLogger object at 0x00000210351D4EB0>)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.576
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.831
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.679
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.013
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.426
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.705
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.412
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.656
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.656
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.094
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.571
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.771

# %% [markdown]
# ### Need to save the model

# %%
# make a folder for the model to live in
try:
    os.mkdir("../model")
except FileExistsError:
    pass

# %%
# save the model
torch.save(model.state_dict(), "../model/glomeruli_detection_model")

# %% [markdown]
# ### Visualize the predictions

# %%
# load the model that we just made
loaded_model = get_model(num_classes = 2)
loaded_model.load_state_dict(torch.load("../model/glomeruli_detection_model"))
# Out:
# <All keys matched successfully>

# %%
idx = 1
img, _ = dataset_test[idx]
label_boxes = np.array(dataset_test[idx][1]["boxes"])

# put the model in evaluation mode
loaded_model.eval()
with torch.no_grad():
    prediction = loaded_model([img])

# turn the test images from tensor arrays to PIL image
x = img*255
image = ToPILImage()(x) 

# draw the boxes around the predicted glomeruli, return the image
draw = ImageDraw.Draw(image)
for elem in range(len(label_boxes)):
    draw.rectangle([(label_boxes[elem][0], label_boxes[elem][1]),
    (label_boxes[elem][2], label_boxes[elem][3])], 
    outline ="black", width =3)

for element in range(len(prediction[0]["boxes"])):
    boxes = prediction[0]["boxes"][element].cpu().numpy()
    score = np.round(prediction[0]["scores"][element].cpu().numpy(),
                    decimals= 4)
    
    if score > 0.80:
        draw.rectangle([(boxes[0], boxes[1]), (boxes[2], boxes[3])], 
                        outline ='white', width =3)
        draw.text((boxes[0], boxes[1]), text = str(score))
                
image
# Out:
# <PIL.Image.Image image mode=L size=774x545 at 0x21003AC0A90>

# %% [markdown]
# ### Make a test class

# %%
class TestingDataset(torch.utils.data.Dataset):
    def __init__(self, root, transforms=None):
        self.root = root
        self.transforms = transforms
        self.imgs = sorted(os.listdir(os.path.join(root, 'test/images/slices')))
    def __getitem__(self, idx):
        # load images and bounding boxes
        img_path = os.path.join(self.root,'test/images/slices', self.imgs[idx])
        img = tiff.imread(img_path)
        if len(img.shape) == 5:
            img = img.squeeze().transpose(1, 2, 0)
        
        # there is only one class
        image_id = torch.tensor([idx])
        imgid = self.imgs[idx]
        target = {}
        if self.transforms is not None:
            img = self.transforms(img, target)
        return img, imgid
    def __len__(self):
        return len(self.imgs)

# %%
testset = TestingDataset(root = '..', 
                         transforms = get_transform(train=False))
testset.__getitem__(0)
# Out:
# ((tensor([[[0.0000, 0.0000, 0.0000,  ..., 0.8353, 0.8353, 0.8353],
#            [0.0000, 0.0000, 0.0000,  ..., 0.8353, 0.8353, 0.8353],
#            [0.0000, 0.0000, 0.0000,  ..., 0.8353, 0.8353, 0.8353],
#            ...,
#            [0.0000, 0.0000, 0.0000,  ..., 0.8353, 0.8353, 0.8392],
#            [0.0000, 0.0000, 0.0000,  ..., 0.8353, 0.8353, 0.8392],
#            [0.0000, 0.0000, 0.0000,  ..., 0.8392, 0.8353, 0.8353]]]),
#   {}),
#  '26dc41664_0_0.tiff')

# %% [markdown]
# ### Use model on Test images

# %%
loaded_model = get_model(num_classes = 2)
loaded_model.load_state_dict(torch.load("../model/glomeruli_detection_model"))
# Out:
# <All keys matched successfully>

# %%
# %%time
if torch.cuda.is_available():
    loaded_model.cuda()

loaded_model.eval()

predictions = []
for i in range(len(testset)):
    predict = {}
    tensor_img = testset[i][0][0][None, :,:].to(device)
    
    with torch.no_grad():
        preds = loaded_model(tensor_img)
        predictions.append(preds)
# Out:
# Wall time: 10min 26s

# %% [markdown]
# ### Turn predictions into a dataframe and save as a csv

# %%
prediction =[]

# %%
predictions[0][0]
# Out:
# {'boxes': tensor([[ 21.2187,  20.8178, 348.1617, 579.3714]], device='cuda:0'),
#  'labels': tensor([1], device='cuda:0'),
#  'scores': tensor([0.1147], device='cuda:0')}

# %%
for x in range(len(predictions)):
    prediction.append(predictions[x][0])

# %%
test_preds = pd.DataFrame(prediction)

# %%
test_preds['filename'] = testset.imgs

# %%
test_preds = test_preds[['filename', 'boxes', 'scores', 'labels']]

# %%
test_preds.to_csv('../CSVs/test_preds.csv', index=False)

# %% [markdown]
# ### Visualize predictions

# %%
idx = 2635

img, _ = testset[idx][0]

# turn the test images from tensor arrays to PIL image
x = img*255
image = ToPILImage()(x) 

# draw the boxes around the predicted glomeruli, return the image
draw = ImageDraw.Draw(image)

for ele in range(len(test_preds.loc[idx]['boxes'])):
    boxes = prediction[idx]['boxes'][ele].cpu().numpy()
    score = np.round(prediction[idx]["scores"][ele].cpu().numpy(),
                    decimals= 4)
    if score > 0.91:
        draw.rectangle([(boxes[0], boxes[1]), (boxes[2], boxes[3])], 
        outline ='white', width =3)
        draw.text((boxes[0], boxes[1]), text = str(score))
image
# Out:
# <PIL.Image.Image image mode=L size=631x488 at 0x21035236460>
